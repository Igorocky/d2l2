# %%
import numpy
import cv2
import os
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:/Users/Igor/igye/projects/python/Learning-OpenCV-4-Computer-Vision-with-Python-Third-Edition/chapter02/MyPic.png')
my_roi = img[0:100, 0:100]
img[100:200, 50:150] = my_roi
plt.imshow(img)
